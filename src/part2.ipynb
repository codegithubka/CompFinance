# %% [markdown]
# ### Hedging: Volatility Mismatch
#
# Consider a short position in a European call option on a non-dividend paying stock with a maturity of one year and strike K = 99 EUR. Let the one-year risk-free interest rate be 6% and the current stock price be 100 EUR. Furthermore, assume that the volatility is 20%.
#
# Use the Euler method to perform a hedging simulation.

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# %% [markdown]
# ### Model Construction

# %% [markdown]
# #### 1. Matching Volatility
#
# Conduct an experiment where the volatility in the stock price process matches the volatility used in the delta computation (i.e., both set to 20%). Vary the frequency of hedge adjustments (from daily to weekly) and explain the results.

# %%
# Parameters

S0 = 100 # Spot price
K = 99 # strike price
T = 1.0 # maturity
r = 0.06 # risk-free rate
sigma = 0.20 # volatility (real same as implied for task 1)

def get_call_price(S, t, K, T, r, sigma):
    """Black-Scholes European call price (eq. 91)"""
    tau = T - t
    if tau <= 0:
        return max(S - K, 0)
    d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * tau) / (sigma * np.sqrt(tau))
    d2 = d1 - sigma * np.sqrt(tau)
    return S * norm.cdf(d1) - K * np.exp(-r * tau) * norm.cdf(d2)

def get_delta(S, t, K, T, r, sigma):
    """Black Scholes delta = N(d1) (eq.97 + Greeks table)"""
    tau = T - t
    if tau <= 0:
        return 1.0 if S > K else 0.0
    d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * tau) / (sigma * np.sqrt(tau))
    return norm.cdf(d1)

# %%
def simulate_hedge(S0, T, K, r, sigma_r, sigma_i, N_steps, seed = None):
    """
    Simulate one delta-hedge path.
    
    sigma_r: volatility driving the stock
    sigma_i: volatility used for option pricing and delta calculation (implied volatility)
    
    """
    
    if seed is not None:
        np.random.seed(seed)
        
    dt = T / N_steps # time step
    S = np.zeros(N_steps + 1)
    S[0] = S0 # set spot price
    
    # Simulate stock path via Euler scheme
    Z = np.random.randn(N_steps)
    for i in range(N_steps):
        S[i+1] = S[i] + r * S[i] * dt + sigma_r * S[i] * np.sqrt(dt) * Z[i] # standard EM scheme for GBM
        
    # Init hedge
    delta_0 = get_delta(S[0], 0, K, T, r, sigma_i) # Initial delta based on the initial price and time
    C0 = get_call_price(S[0], 0, K, T, r, sigma_i) # Initial option price
    B = C0 - delta_0 * S[0] # Bank acccount: initial option price - initial stock position
    delta_old = delta_0
    
    # Rebalance at each step
    for i in range(1, N_steps):
        t_i = i * dt
        B = B * np.exp(r * dt) # Bank account grows at risk-free rate
        delta_new = get_delta(S[i], t_i, K, T, r, sigma_i) # New delta based on current price and time
        B = B - (delta_new - delta_old) * S[i]           # Rebalance: adjust bank account by the cost of changing the stock position
        delta_old = delta_new
        
    # Final PnL at maturity
    B = B * np.exp(r * dt)  
    payoff = max(S[-1] - K, 0)   # Option settlement
    PnL = B + delta_old * S[-1] - payoff # Total PnL: bank account + final stock position - option payoff
    
    return PnL, S

# %%
# Monte Carlo across different rebalancing frequnecies
n_sims = 10_000
frequencies = {                 # NOTE: We can change these frequnecies
    "Daily (N=252)": 252,
    "Every 2 days (N=126)": 126,
    "Weekly (N=52)": 52,
    "Biweekly (N=26)": 26,
}

sigma_i = 0.20
sigma_r = 0.20

results = {}
for label, N in frequencies.items():
    pnls = []
    for sim in range(n_sims):
        pnl, _ = simulate_hedge(S0, T, K, r, sigma_r, sigma_i, N, seed=sim)
        pnls.append(pnl)
    results[label] = np.array(pnls)
    
    print(f"{label}:")
    print(f"  Mean PnL:  {np.mean(pnls):.4f}")
    print(f"  Std PnL:   {np.std(pnls):.4f}")
    print()
# Out:
# Daily (N=252):
#   Mean PnL:  -0.0054
#   Std PnL:   0.4267
#
# Every 2 days (N=126):
#   Mean PnL:  -0.0106
#   Std PnL:   0.6030
#
# Weekly (N=52):
#   Mean PnL:  -0.0020
#   Std PnL:   0.9358
#
# Biweekly (N=26):
#   Mean PnL:  -0.0038
#   Std PnL:   1.3136

# %% [markdown]
# #### Interpretation
#
# ---

# %% [markdown]
# #### 2. Mismatched Volatility
#
# Perform numerical experiments where the volatility in the stock price process does not match the volatility used in the delta valuation. Run computational experiments for various levels of volatility and discuss the outcomes.

# %%
# Task 2: Mismatched Volatility
sigma_imp = 0.20
sigma_real_grid = [0.10, 0.15, 0.20, 0.25, 0.30]
N_steps = 252
n_simulations = 10_000


results_mismatch = {}
for sigma_real in sigma_real_grid:
    pnls = []
    for sim in range(n_simulations):
        pnl, _ = simulate_hedge(S0, T, K, r, sigma_real, sigma_imp, N_steps, seed=sim)
        pnls.append(pnl)
    results_mismatch[sigma_real] = np.array(pnls)
    print(f"σ_real = {sigma_real:.2f}:")
    print(f"  Mean PnL:  {np.mean(pnls):.4f}")
    print(f"  Std PnL:   {np.std(pnls):.4f}")
# Out:
# σ_real = 0.10:
#   Mean PnL:  3.5862
#   Std PnL:   1.1181
# σ_real = 0.15:
#   Mean PnL:  1.8635
#   Std PnL:   0.7369
# σ_real = 0.20:
#   Mean PnL:  -0.0054
#   Std PnL:   0.4267
# σ_real = 0.25:
#   Mean PnL:  -1.9297
#   Std PnL:   1.0024
# σ_real = 0.30:
#   Mean PnL:  -3.8816
#   Std PnL:   1.9202

# %% [markdown]
# #### Interpretation
#
# ---

# %% [markdown]
# #### 3. Pricing and Hedging with Implied Volatility

# %% [markdown]
# **Proposition.** For the expected cumulative P&L to vanish under $\mathbb{P}$, i.e. $\mathbb{E}^{\mathbb{P}}[\mathrm{PnL}] = 0$, it is necessary and sufficient that
#
# $$
# \mathbb{E}^{\mathbb{P}}\!\left[\int_{0}^{T} e^{-rt}\,\frac{1}{2}\,S_t^{2}\,\frac{\partial^{2} C_{\sigma_{\mathrm{imp}}}}{\partial S_t^{2}}\,\left(\sigma_{\mathrm{imp}}^{2} - \sigma_t^{2}\right)\,\mathrm{d}t\right] = 0
# $$
#
# ---
#
# **Proof:** Assume that for an underlying with spot price $S_t$, vanilla option with value function $C(t,S_t,\sigma_{imp}) = C_{\sigma_{\mathrm{imp}}}$ is priced under the risk neutral measure by solving the BS PDE with implied volatility $\sigma_{imp}$:
#
# $$
#   \frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial t}
#   + r\,S_t\,\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t}
#   + \tfrac{1}{2}\,\sigma_{imp}^{2}\,S_t^{2}\,
#     \frac{\partial^{2}C}{\partial S_t^{2}}
#   - r\,C_{\sigma_{\mathrm{imp}}} = 0
# $$
#
# with terminal condition $C(T,S_T) = (S_T - K)^{+}$.
#
# Under the objective physical measure $\mathbb{P}$ the underlying follows:
#
# $$
#   \frac{\mathrm{d} S_t}{S_t} = r\,\mathrm{d} t + \sigma_t\,\mathrm{d} W_t^{\mathbb{P}},
# $$
#
# where $\sigma_t$ denotes the instantaneous realized volatility.
#
# We hedge the short position at each time $t$ bu holding:
#
# $$
#   \Delta_t
#   = \frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t}
# $$
#
# shares of the underlying, financed at the risk free rate $r$.
#
# Applying Ito's Lemma to $C(t, S_t, \sigma_{imp})$ along the real world path:
#
# $$
#   \mathrm{d} C_{\sigma_{\mathrm{imp}}}
#   = \biggl(
#       \frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial t}
#       + r\,S_t\,\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t}
#       + \tfrac{1}{2}\,\sigma_t^{2}\,S_t^{2}\,
#         \frac{\partial^{2}C}{\partial S_t^{2}}
#     \biggr)\mathrm{d} t
#     + \sigma_t\,S_t\,\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t}\,\mathrm{d} W_t^{\mathbb{P}}.
# $$
#
# Here, the second order term uses the realized volatilty, $\sigma_t$, that drives the asset price $S_t$.
#
# Now, consider our self-financing portfolio that is short one option and long $\Delta_t$ shares. Over the interval $[t, t + dt]$ the P&L of the hedge is given by
#
# $$
#   \mathrm{d}\mathrm{PnL}_t
#   = -\,\mathrm{d} C_{\sigma_{\mathrm{imp}}} + \Delta_t\,\mathrm{d} S_t + r\bigl(C_{\sigma_{\mathrm{imp}}} - \Delta_t\,S_t\bigr)\mathrm{d} t.
# $$
#
# which can be decomposed as the loss from the short option, the gain from the delta shares, and the interest earned on the net cash balance.
#
# Substituting $\Delta_t = \partial C_{\sigma_{\mathrm{imp}}} / \partial S_t$ and $\mathrm{d} S_t = r\,S_t\,\mathrm{d} t + \sigma_t\,S_t\,\mathrm{d} W_t^{\mathbb{P}}$ into the above equation, we have
#
# Substituting all three into the P&L expression and writing every term explicitly:
#
# $$
# \mathrm{d}\mathrm{PnL}_t = -\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial t}\,\mathrm{d}t - r\,S_t\,\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t}\,\mathrm{d}t - \frac{1}{2}\,\sigma_t^2\,S_t^2\,\frac{\partial^2 C_{\sigma_{\mathrm{imp}}}}{\partial S_t^2}\,\mathrm{d}t - \sigma_t\,S_t\,\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t}\,\mathrm{d}W_t^{\mathbb{P}}
# $$
#
# $$
# + \frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t}\,r\,S_t\,\mathrm{d}t + \frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t}\,\sigma_t\,S_t\,\mathrm{d}W_t^{\mathbb{P}}
# $$
#
# $$
# + r\,C_{\sigma_{\mathrm{imp}}}\,\mathrm{d}t - r\,S_t\,\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t}\,\mathrm{d}t
# $$
#
# where the first line comes from $-\mathrm{d}C_{\sigma_{\mathrm{imp}}}$, the second line from $+\Delta_t\,\mathrm{d}S_t$, and the third line from $r(C_{\sigma_{\mathrm{imp}}} - \Delta_t\,S_t)\,\mathrm{d}t$.
#
# The two $\mathrm{d}W_t^{\mathbb{P}}$ terms cancel:
#
# $$
# -\sigma_t\,S_t\,\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t}\,\mathrm{d}W_t^{\mathbb{P}} + \sigma_t\,S_t\,\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t}\,\mathrm{d}W_t^{\mathbb{P}} = 0
# $$
#
# The term $r\,S_t\,\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t}$ appears three times so we have:
#
# $$
# -r\,S_t\,\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t} + r\,S_t\,\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t} - r\,S_t\,\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t} = -r\,S_t\,\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t}
# $$
#
# After cancellations, we obtain:
#
# $$
# \mathrm{d}\mathrm{PnL}_t = \left[-\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial t} - r\,S_t\,\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t} - \frac{1}{2}\,\sigma_t^2\,S_t^2\,\frac{\partial^2 C_{\sigma_{\mathrm{imp}}}}{\partial S_t^2} + r\,C_{\sigma_{\mathrm{imp}}}\right]\mathrm{d}t
# $$
#
# Since $C_{\sigma_{\mathrm{imp}}}$ satisfies:
#
# $$
# \frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial t} + r\,S_t\,\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t} + \frac{1}{2}\,\sigma_{\mathrm{imp}}^2\,S_t^2\,\frac{\partial^2 C_{\sigma_{\mathrm{imp}}}}{\partial S_t^2} - r\,C_{\sigma_{\mathrm{imp}}} = 0
# $$
#
# we can substitute $-\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial t} - r\,S_t\,\frac{\partial C_{\sigma_{\mathrm{imp}}}}{\partial S_t} + r\,C_{\sigma_{\mathrm{imp}}} = \frac{1}{2}\,\sigma_{\mathrm{imp}}^2\,S_t^2\,\frac{\partial^2 C_{\sigma_{\mathrm{imp}}}}{\partial S_t^2}$ into the expression above:
#
# $$
# \mathrm{d}\mathrm{PnL}_t = \left[\frac{1}{2}\,\sigma_{\mathrm{imp}}^2\,S_t^2\,\frac{\partial^2 C_{\sigma_{\mathrm{imp}}}}{\partial S_t^2} - \frac{1}{2}\,\sigma_t^2\,S_t^2\,\frac{\partial^2 C_{\sigma_{\mathrm{imp}}}}{\partial S_t^2}\right]\mathrm{d}t
# $$
#
# Re-arranging, we get
# $$
# {\mathrm{d}\mathrm{PnL}_t = \frac{1}{2}\,S_t^2\,\frac{\partial^2 C_{\sigma_{\mathrm{imp}}}}{\partial S_t^2}\left(\sigma_{\mathrm{imp}}^2 - \sigma_t^2\right)\mathrm{d}t}
# $$
#
# This is the instantaneous carry P&L due to volatility mismatch.
#
# To obtain the total P&L at maturity, we discount each instantaneous contribution to time $t = 0$ and integrate:
#
# $$
# \mathrm{PnL} = \int_{0}^{T} e^{-rt}\,\mathrm{d}\mathrm{PnL}_t = \int_{0}^{T} e^{-rt}\,\frac{1}{2}\,S_t^{2}\,\frac{\partial^{2} C_{\sigma_{\mathrm{imp}}}}{\partial S_t^{2}}\,\left(\sigma_{\mathrm{imp}}^{2} - \sigma_t^{2}\right)\,\mathrm{d}t
# $$
#
# Now impose the condition $\mathbb{E}^{\mathbb{P}}[\mathrm{PnL}] = 0$. By linearity of expectation:
#
# $$
# \mathbb{E}^{\mathbb{P}}[\mathrm{PnL}] = \mathbb{E}^{\mathbb{P}}\!\left[\int_{0}^{T} e^{-rt}\,\frac{1}{2}\,S_t^{2}\,\frac{\partial^{2} C_{\sigma_{\mathrm{imp}}}}{\partial S_t^{2}}\,\left(\sigma_{\mathrm{imp}}^{2} - \sigma_t^{2}\right)\,\mathrm{d}t\right]
# $$
#
# Since $\sigma_{\mathrm{imp}}$ is a fixed constant, we can split the integral:
#
# $$
# = \int_{0}^{T} e^{-rt}\,\frac{1}{2}\,\sigma_{\mathrm{imp}}^{2}\,\mathbb{E}^{\mathbb{P}}\!\left[S_t^{2}\,\frac{\partial^{2} C_{\sigma_{\mathrm{imp}}}}{\partial S_t^{2}}\right]\mathrm{d}t - \int_{0}^{T} e^{-rt}\,\frac{1}{2}\,\mathbb{E}^{\mathbb{P}}\!\left[\sigma_t^{2}\,S_t^{2}\,\frac{\partial^{2} C_{\sigma_{\mathrm{imp}}}}{\partial S_t^{2}}\right]\mathrm{d}t
# $$
#
# Setting this equal to zero:
#
# $$
# \int_{0}^{T} e^{-rt}\,\frac{1}{2}\,\sigma_{\mathrm{imp}}^{2}\,\mathbb{E}^{\mathbb{P}}\!\left[S_t^{2}\,\frac{\partial^{2} C_{\sigma_{\mathrm{imp}}}}{\partial S_t^{2}}\right]\mathrm{d}t = \int_{0}^{T} e^{-rt}\,\frac{1}{2}\,\mathbb{E}^{\mathbb{P}}\!\left[\sigma_t^{2}\,S_t^{2}\,\frac{\partial^{2} C_{\sigma_{\mathrm{imp}}}}{\partial S_t^{2}}\right]\mathrm{d}t
# $$
#
# This says that $\sigma_{\mathrm{imp}}^2$ must equal the future realized variance $\sigma_t^2$ on average, as desired
